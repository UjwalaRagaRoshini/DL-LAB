# %% [markdown]
# <a href="https://colab.research.google.com/github/UjwalaRagaRoshini/DL-LAB/blob/main/Multiclass_classification_using_Reuters_Newswire_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)

# %%
#Each review (row) is of different size. This data needs to be made uniform.
# i.e. each reviuew (i.e. row) needs to be onehotencoded to a length of 10,000 (we have decided to have only 10000 features)
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
#create the layers
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 1s 61ms/step - loss: 0.1274 - categorical_accuracy: 0.9569 - val_loss: 1.0103 - val_categorical_accuracy: 0.8087
# Epoch 2/25
# 16/16 [==============================] - 1s 44ms/step - loss: 0.1183 - categorical_accuracy: 0.9588 - val_loss: 1.0291 - val_categorical_accuracy: 0.8125
# Epoch 3/25
# 16/16 [==============================] - 1s 39ms/step - loss: 0.1100 - categorical_accuracy: 0.9589 - val_loss: 1.0999 - val_categorical_accuracy: 0.7875
# Epoch 4/25
# 16/16 [==============================] - 1s 33ms/step - loss: 0.1113 - categorical_accuracy: 0.9567 - val_loss: 1.0740 - val_categorical_accuracy: 0.7975
# Epoch 5/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1091 - categorical_accuracy: 0.9588 - val_loss: 1.0297 - val_categorical_accuracy: 0.8087
# Epoch 6/25
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1048 - categorical_accuracy: 0.9589 - val_loss: 1.0676 - val_categorical_accuracy: 0.8025
# Epoch 7/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1069 - categorical_accuracy: 0.9580 - val_loss: 1.0481 - val_categorical_accuracy: 0.8012
# Epoch 8/25
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1048 - categorical_accuracy: 0.9583 - val_loss: 1.0976 - val_categorical_accuracy: 0.8025
# Epoch 9/25
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1057 - categorical_accuracy: 0.9572 - val_loss: 1.0635 - val_categorical_accuracy: 0.8025
# Epoch 10/25
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1002 - categorical_accuracy: 0.9591 - val_loss: 1.0982 - val_categorical_accuracy: 0.7937
# Epoch 11/25
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1018 - categorical_accuracy: 0.9587 - val_loss: 1.1212 - val_categorical_accuracy: 0.7937
# Epoch 12/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1004 - categorical_accuracy: 0.9575 - val_loss: 1.0798 - val_categorical_accuracy: 0.7987
# Epoch 13/25
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0973 - categorical_accuracy: 0.9583 - val_loss: 1.1066 - val_categorical_accuracy: 0.8050
# Epoch 14/25
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0994 - categorical_accuracy: 0.9591 - val_loss: 1.1129 - val_categorical_accuracy: 0.7987
# Epoch 15/25
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0965 - categorical_accuracy: 0.9600 - val_loss: 1.1193 - val_categorical_accuracy: 0.8000
# Epoch 16/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1017 - categorical_accuracy: 0.9572 - val_loss: 1.1038 - val_categorical_accuracy: 0.8050
# Epoch 17/25
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0960 - categorical_accuracy: 0.9594 - val_loss: 1.1445 - val_categorical_accuracy: 0.7925
# Epoch 18/25
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0964 - categorical_accuracy: 0.9588 - val_loss: 1.1069 - val_categorical_accuracy: 0.8138
# Epoch 19/25
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0976 - categorical_accuracy: 0.9588 - val_loss: 1.1215 - val_categorical_accuracy: 0.8000
# Epoch 20/25
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0989 - categorical_accuracy: 0.9569 - val_loss: 1.1067 - val_categorical_accuracy: 0.8025
# Epoch 21/25
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0957 - categorical_accuracy: 0.9583 - val_loss: 1.1240 - val_categorical_accuracy: 0.7925
# Epoch 22/25
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0941 - categorical_accuracy: 0.9605 - val_loss: 1.1674 - val_categorical_accuracy: 0.7950
# Epoch 23/25
# 16/16 [==============================] - 1s 43ms/step - loss: 0.0915 - categorical_accuracy: 0.9614 - val_loss: 1.1099 - val_categorical_accuracy: 0.8087
# Epoch 24/25
# 16/16 [==============================] - 1s 40ms/step - loss: 0.0930 - categorical_accuracy: 0.9603 - val_loss: 1.1108 - val_categorical_accuracy: 0.8025
# Epoch 25/25
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0924 - categorical_accuracy: 0.9593 - val_loss: 1.1546 - val_categorical_accuracy: 0.7962

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
